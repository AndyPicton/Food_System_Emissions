# %%
#Import dependencies
import pandas as pd

# %% [markdown]
# ## Using pd.melt to verticalize a table
# - melting (cleaned_sector_emi_df_copy.csv) on all years

# %%
#import csv
df = pd.read_csv("cleaned_sector_emi_df_copy.csv", index_col = 0)
df
# Out:
#      Country_code_A3      Name      C_group_IM24_sh dev_country    Substance  \
# 0                AGO    Angola  10:_Southern_Africa           D  GWP_100_CO2
# 1                AGO    Angola  10:_Southern_Africa           D  GWP_100_CH4
# 2                AGO    Angola  10:_Southern_Africa           D  GWP_100_N2O
# 3                ALB   Albania   12:_Central Europe           I  GWP_100_CO2
# 4                ALB   Albania   12:_Central Europe           I  GWP_100_N2O
# ...              ...       ...                  ...         ...          ...
# 4840             ZWE  Zimbabwe  10:_Southern_Africa           D  GWP_100_N2O
# 4841             ZWE  Zimbabwe  10:_Southern_Africa           D  GWP_100_N2O
# 4842             ZWE  Zimbabwe  10:_Southern_Africa           D  GWP_100_N2O
# 4843             ZWE  Zimbabwe  10:_Southern_Africa           D  GWP_100_N2O
# 4844             ZWE  Zimbabwe  10:_Southern_Africa           D  GWP_100_N2O
#
# ...

# %%
list(df)
# Out:
# ['Country_code_A3',
#  'Name',
#  'C_group_IM24_sh',
#  'dev_country',
#  'Substance',
#  'FOOD_system_stage',
#  'Y_1990',
#  'Y_1991',
#  'Y_1992',
#  'Y_1993',
#  'Y_1994',
#  'Y_1995',
#  'Y_1996',
#  'Y_1997',
#  'Y_1998',
#  'Y_1999',
#  'Y_2000',
#  'Y_2001',
#  'Y_2002',
#  'Y_2003',
#  'Y_2004',
#  'Y_2005',
#  'Y_2006',
#  'Y_2007',
#  'Y_2008',
#  'Y_2009',
#  'Y_2010',
#  'Y_2011',
#  'Y_2012',
#  'Y_2013',
#  'Y_2014',
#  'Y_2015',
#  'Y_2016',
#  'Y_2017',
#  'Y_2018']

# %%
#renaming columns
df.rename(columns = {'Country_code_A3':'country_code', 'C_group_IM24_sh':'region', 'dev_country': 'country_class',
                         'FOOD_system_stage': 'food_system_stage', 'Y_1990':'1990', 'Y_1991':'1991', 'Y_1992':'1992',
                            'Y_1993':'1993', 'Y_1994':'1994', 'Y_1995':'1995', 'Y_1996':'1996','Y_1997':'1997', 'Y_1998':'1998',
                                'Y_1999':'1999', 'Y_2000':'2000','Y_2001':'2001', 'Y_2002':'2002', 'Y_2003':'2003', 'Y_2004':'2004',
                                    'Y_2005':'2005', 'Y_2006':'2006', 'Y_2007':'2007', 'Y_2008':'2008', 'Y_2009':'2009', 'Y_2010':'2010', 
                                        'Y_2011':'2011', 'Y_2012':'2012', 'Y_2013':'2013', 'Y_2014':'2014', 'Y_2015':'2015', 'Y_2016':'2016', 
                                            'Y_2017':'2017', 'Y_2018':'2018'}, inplace = True)

# %%
# checking columns
list(df)
# Out:
# ['country_code',
#  'Name',
#  'region',
#  'country_class',
#  'Substance',
#  'food_system_stage',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018']

# %%
#pd melt example

# Create a simple dataframe
  
# importing pandas as pd
import pandas as pd
  
# creating a dataframe
ex = pd.DataFrame({'Name': {0: 'John', 1: 'Bob', 2: 'Shiela'},
                   'Course': {0: 'Masters', 1: 'Graduate', 2: 'Graduate'},
                   'Age': {0: 27, 1: 23, 2: 21}})
ex
# Out:
#      Name    Course  Age
# 0    John   Masters   27
# 1     Bob  Graduate   23
# 2  Shiela  Graduate   21

# %%
# Name is id_vars and Course is value_vars
pd.melt(ex, id_vars =['Name'], value_vars =['Course'])
# Out:
#      Name variable     value
# 0    John   Course   Masters
# 1     Bob   Course  Graduate
# 2  Shiela   Course  Graduate

# %%
#using pd.melt on df
df_melted = pd.melt(df, id_vars=['Name','region','country_class','Substance','food_system_stage'],value_vars=['1990','1991','1992','1993','1994', '1995', '1996', '1997', '1998', '1999', '2000','2001','2002','2003','2004','2005','2006', '2007','2008', '2009', '2010','2011','2012', '2013', '2014', '2015', '2016', '2017', '2018'], value_name ="ghg_emissions (kt CO2eq)")
df_melted
# Out:
#             Name               region country_class    Substance  \
# 0         Angola  10:_Southern_Africa             D  GWP_100_CO2
# 1         Angola  10:_Southern_Africa             D  GWP_100_CH4
# 2         Angola  10:_Southern_Africa             D  GWP_100_N2O
# 3        Albania   12:_Central Europe             I  GWP_100_CO2
# 4        Albania   12:_Central Europe             I  GWP_100_N2O
# ...          ...                  ...           ...          ...
# 139050  Zimbabwe  10:_Southern_Africa             D  GWP_100_N2O
# 139051  Zimbabwe  10:_Southern_Africa             D  GWP_100_N2O
# 139052  Zimbabwe  10:_Southern_Africa             D  GWP_100_N2O
# 139053  Zimbabwe  10:_Southern_Africa             D  GWP_100_N2O
# 139054  Zimbabwe  10:_Southern_Africa             D  GWP_100_N2O
#
#          food_system_stage variable  ghg_emissions (kt CO2eq)
# 0       LULUC (Production)     1990              10273.545100
# ...

# %% [markdown]
# ### Transforming names
# - transforming substance, possibly region
# - Python replace() method to update string values in a dataframe
# - form: dataframe.replace("old string", "new string")

# %%
#list of unique values in 'region'
df_melted.region.unique()
# Out:
# array(['10:_Southern_Africa', '12:_Central Europe',
#        '06:_Rest South America', '16:_Russia +', '24:_Oceania',
#        '11:_OECD_Europe', '09:_Eastern_Africa', '08:_Western_Africa',
#        '18:_India +', '04:_Rest Central America', '14:_Ukraine +',
#        '05:_Brazil', '21:_Southeastern Asia', '01:_Canada', '20:_China +',
#        '07:_Northern_Africa', '22:_Indonesia +', '17:_Middle_East',
#        '23:_Japan', '15:_Asia-Stan', '19:_Korea', '03:_Mexico', '02:_USA',
#        '13:_Turkey', '28:_Int. Aviation', '27:_Int. Shipping'],
#       dtype=object)

# %%
#cleaning region names
df_melted_clean = df_melted.replace({'region': { '10:_Southern_Africa': 'Southern Africa','12:_Central Europe':'Central Europe',
                              '06:_Rest South America':'Rest South America', '16:_Russia +':'Russia', '24:_Oceania':'Oceania',
                             '11:_OECD_Europe':'OECD Europe','09:_Eastern_Africa':'Eastern Africa', '08:_Western_Africa':'Western Africa',
                             '18:_India +':'India','04:_Rest Central America':'Rest Central America', '14:_Ukraine +':'Ukraine', '05:_Brazil':'Brazil',
                             '21:_Southeastern Asia':'Southeastern Asia', '01:_Canada':'Canada', '20:_China +':'China', '07:_Northern_Africa':'Northern Africa',
                             '22:_Indonesia +':'Indonesia','17:_Middle_East':'Middle East', '23:_Japan':'Japan','15:_Asia-Stan':'Asia_Stan','19:_Korea':'Korea', '03:_Mexico':'Mexico', 
                             '02:_USA':'USA', '13:_Turkey':'Turkey', '28:_Int. Aviation':'Int. Aviation','27:_Int. Shipping':'Int. Shipping'}})

# %%
df_melted_clean
# Out:
#             Name           region country_class    Substance  \
# 0         Angola  Southern Africa             D  GWP_100_CO2
# 1         Angola  Southern Africa             D  GWP_100_CH4
# 2         Angola  Southern Africa             D  GWP_100_N2O
# 3        Albania   Central Europe             I  GWP_100_CO2
# 4        Albania   Central Europe             I  GWP_100_N2O
# ...          ...              ...           ...          ...
# 139050  Zimbabwe  Southern Africa             D  GWP_100_N2O
# 139051  Zimbabwe  Southern Africa             D  GWP_100_N2O
# 139052  Zimbabwe  Southern Africa             D  GWP_100_N2O
# 139053  Zimbabwe  Southern Africa             D  GWP_100_N2O
# 139054  Zimbabwe  Southern Africa             D  GWP_100_N2O
#
#          food_system_stage variable  ghg_emissions (kt CO2eq)
# 0       LULUC (Production)     1990              10273.545100
# 1       LULUC (Production)     1990               7662.485600
# ...

# %%
#unique values
df_melted_clean.Substance.unique()
# Out:
# array(['GWP_100_CO2', 'GWP_100_CH4', 'GWP_100_N2O', 'GWP_100_F-gases'],
#       dtype=object)

# %%
#cleaning emission names
edgar_melted = df_melted_clean.replace({'Substance': {'GWP_100_CO2':'CO2', 'GWP_100_CH4':'CH4','GWP_100_N2O':'N2O', 'GWP_100_F-gases':'F-gases'}})
edgar_melted
# Out:
#             Name           region country_class Substance   food_system_stage  \
# 0         Angola  Southern Africa             D       CO2  LULUC (Production)
# 1         Angola  Southern Africa             D       CH4  LULUC (Production)
# 2         Angola  Southern Africa             D       N2O  LULUC (Production)
# 3        Albania   Central Europe             I       CO2  LULUC (Production)
# 4        Albania   Central Europe             I       N2O  LULUC (Production)
# ...          ...              ...           ...       ...                 ...
# 139050  Zimbabwe  Southern Africa             D       N2O           Packaging
# 139051  Zimbabwe  Southern Africa             D       N2O          Processing
# 139052  Zimbabwe  Southern Africa             D       N2O          Production
# 139053  Zimbabwe  Southern Africa             D       N2O              Retail
# 139054  Zimbabwe  Southern Africa             D       N2O           Transport
#
# ...

# %%
#converting df_melted to csv
edgar_melted.to_csv('/Users/cameronchapa/Downloads/School Related/Bootcamp Stuff/Analysis Projects/Final Project/Group_10_Final_Project/Cam/Data/edgar_melted.csv', index = False)

# %%
import json
import pandas as pd
import numpy as np


from sqlalchemy import create_engine, func, inspect
import psycopg2

# from config import db_password
from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@group-10-final.cu1buh4bpqlm.us-east-2.rds.amazonaws.com:5432/group-10-final"
engine = create_engine(db_string)

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['ghg_food_sys_emi',
#  'ml_table_2018',
#  'cleaned_sector_emi',
#  'cleaned_country_def',
#  'edgar_food_switched',
#  'total_ghg_country_type',
#  'edgar_switched_join']

# %%
pd.read_sql_query('''SELECT * FROM cleaned_sector_emi ;''', engine)
# Out:
#       index Country_code_A3      Name      C_group_IM24_sh dev_country  \
# 0         0             AGO    Angola  10:_Southern_Africa           D
# 1         1             AGO    Angola  10:_Southern_Africa           D
# 2         2             AGO    Angola  10:_Southern_Africa           D
# 3         3             ALB   Albania   12:_Central Europe           I
# 4         4             ALB   Albania   12:_Central Europe           I
# ...     ...             ...       ...                  ...         ...
# 4790   4840             ZWE  Zimbabwe  10:_Southern_Africa           D
# 4791   4841             ZWE  Zimbabwe  10:_Southern_Africa           D
# 4792   4842             ZWE  Zimbabwe  10:_Southern_Africa           D
# 4793   4843             ZWE  Zimbabwe  10:_Southern_Africa           D
# 4794   4844             ZWE  Zimbabwe  10:_Southern_Africa           D
#
#         Substance   FOOD_system_stage        Y_1990        Y_1991  \
# ...

# %%
cleaned_sector_emi_df = pd.read_sql_query('''SELECT * FROM cleaned_sector_emi ;''', engine)

cleaned_sector_emi_df.head()
# Out:
#    index Country_code_A3     Name      C_group_IM24_sh dev_country  \
# 0      0             AGO   Angola  10:_Southern_Africa           D
# 1      1             AGO   Angola  10:_Southern_Africa           D
# 2      2             AGO   Angola  10:_Southern_Africa           D
# 3      3             ALB  Albania   12:_Central Europe           I
# 4      4             ALB  Albania   12:_Central Europe           I
#
#      Substance   FOOD_system_stage      Y_1990      Y_1991      Y_1992  ...  \
# 0  GWP_100_CO2  LULUC (Production)  10273.5451  10273.5451  10273.5451  ...
# 1  GWP_100_CH4  LULUC (Production)   7662.4856   7662.4856   7662.4856  ...
# 2  GWP_100_N2O  LULUC (Production)   5009.7985   5009.7985   5009.7985  ...
# 3  GWP_100_CO2  LULUC (Production)    116.8068    116.8068    116.8068  ...
# 4  GWP_100_N2O  LULUC (Production)     12.4815     12.4815     12.4815  ...
#
#        Y_2009      Y_2010      Y_2011      Y_2012      Y_2013      Y_2014  \
# ...

# %%
# csv for data verification
cleaned_sector_emi_df.to_csv('cleaned_sector_emi.csv', index=False)

# %%
GHG_ML_df = cleaned_sector_emi_df.drop(cleaned_sector_emi_df.columns[[0, 1, 3]], axis=1)

GHG_ML_df.head()
# Out:
#       Name dev_country    Substance   FOOD_system_stage      Y_1990  \
# 0   Angola           D  GWP_100_CO2  LULUC (Production)  10273.5451
# 1   Angola           D  GWP_100_CH4  LULUC (Production)   7662.4856
# 2   Angola           D  GWP_100_N2O  LULUC (Production)   5009.7985
# 3  Albania           I  GWP_100_CO2  LULUC (Production)    116.8068
# 4  Albania           I  GWP_100_N2O  LULUC (Production)     12.4815
#
#        Y_1991      Y_1992      Y_1993      Y_1994      Y_1995  ...  \
# 0  10273.5451  10273.5451  10273.5451  10273.5451  10271.7160  ...
# 1   7662.4856   7662.4856   7662.4856   7662.4856   7662.4856  ...
# 2   5009.7985   5009.7985   5009.7985   5009.7985   5009.6395  ...
# 3    116.8068    116.8068    116.8068    116.8068    116.8068  ...
# 4     12.4815     12.4815     12.4815     12.4815     12.4815  ...
#
#        Y_2009      Y_2010      Y_2011      Y_2012      Y_2013      Y_2014  \
# 0  35606.0653  35605.4601  35604.1556  35604.1556  35604.1556  35602.6343
# ...

# %%
GHG_ML_2018_df = GHG_ML_df.drop(GHG_ML_df.iloc[:, 4:32], axis=1)

GHG_ML_2018_df.head()
# Out:
#       Name dev_country    Substance   FOOD_system_stage      Y_2018
# 0   Angola           D  GWP_100_CO2  LULUC (Production)  35592.0828
# 1   Angola           D  GWP_100_CH4  LULUC (Production)   4870.0764
# 2   Angola           D  GWP_100_N2O  LULUC (Production)   4252.8790
# 3  Albania           I  GWP_100_CO2  LULUC (Production)    114.1346
# 4  Albania           I  GWP_100_N2O  LULUC (Production)     12.1900

# %%
GHG_ML_2018_df = GHG_ML_2018_df[~GHG_ML_2018_df['Name'].isin(['Int. Aviation', 'Int. Shipping'])]

# %%
# Creating an instance of label encoder

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
LE_ML_2018_df = GHG_ML_2018_df.copy()
LE_ML_2018_df['Substance'] = le.fit_transform(LE_ML_2018_df['Substance'])

# %%
LE_ML_2018_df.head()
# Out:
#       Name dev_country  Substance   FOOD_system_stage      Y_2018
# 0   Angola           D          1  LULUC (Production)  35592.0828
# 1   Angola           D          0  LULUC (Production)   4870.0764
# 2   Angola           D          3  LULUC (Production)   4252.8790
# 3  Albania           I          1  LULUC (Production)    114.1346
# 4  Albania           I          3  LULUC (Production)     12.1900

# %%
# Creating an instance of label encoder

LE_ML_2018_df = LE_ML_2018_df.copy()
LE_ML_2018_df['FOOD_system_stage'] = le.fit_transform(LE_ML_2018_df['FOOD_system_stage'])

# %%
LE_ML_2018_df.head()
# Out:
#       Name dev_country  Substance  FOOD_system_stage      Y_2018
# 0   Angola           D          1                  2  35592.0828
# 1   Angola           D          0                  2   4870.0764
# 2   Angola           D          3                  2   4252.8790
# 3  Albania           I          1                  2    114.1346
# 4  Albania           I          3                  2     12.1900

# %%
# Creating an instance of label encoder

LE_ML_2018_df["Country_Num"] = le.fit_transform(LE_ML_2018_df["Name"])
LE_ML_2018_df.head()
# Out:
#       Name dev_country  Substance  FOOD_system_stage      Y_2018  Country_Num
# 0   Angola           D          1                  2  35592.0828            4
# 1   Angola           D          0                  2   4870.0764            4
# 2   Angola           D          3                  2   4252.8790            4
# 3  Albania           I          1                  2    114.1346            1
# 4  Albania           I          3                  2     12.1900            1

# %%
# Creating an instance of label encoder

DEV_Split = pd.get_dummies(LE_ML_2018_df[['dev_country']])

# %%
LE_ML_2018_df = LE_ML_2018_df.join(DEV_Split)

# %%
# csv for data verification
LE_ML_2018_df.to_csv('LE_ML_2018_V4.csv', index=False)

# %%
LE_ML_2018_df.head()
# Out:
#       Name dev_country  Substance  FOOD_system_stage      Y_2018  Country_Num  \
# 0   Angola           D          1                  2  35592.0828            4
# 1   Angola           D          0                  2   4870.0764            4
# 2   Angola           D          3                  2   4252.8790            4
# 3  Albania           I          1                  2    114.1346            1
# 4  Albania           I          3                  2     12.1900            1
#
#    dev_country_D  dev_country_I
# 0              1              0
# 1              1              0
# 2              1              0
# 3              0              1
# 4              0              1

# %%
Clean_ML_2018_df = LE_ML_2018_df.drop(LE_ML_2018_df.columns[[0, 1]], axis= 1)
Clean_ML_2018_df.head()
# Out:
#    Substance  FOOD_system_stage      Y_2018  Country_Num  dev_country_D  \
# 0          1                  2  35592.0828            4              1
# 1          0                  2   4870.0764            4              1
# 2          3                  2   4252.8790            4              1
# 3          1                  2    114.1346            1              0
# 4          3                  2     12.1900            1              0
#
#    dev_country_I
# 0              0
# 1              0
# 2              0
# 3              1
# 4              1

# %%
# from sklearn.model_selection import train_test_split
# Split preprocessed data into our features and target arrays
#  Target
y = Clean_ML_2018_df["FOOD_system_stage"].values
# Features
X = Clean_ML_2018_df.drop(["FOOD_system_stage"],axis=1).values

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# from sklearn.preprocessing import StandardScaler
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# Create a random forest classifier. 
rf_model = RandomForestClassifier(n_estimators=500, random_state=1)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data.
y_pred = rf_model.predict(X_test_scaled)

# %%
# Display the confustion matrix
# from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[17, 23,  5, 21, 23, 17, 34, 14],
#        [29, 37, 10,  6, 14, 32,  4,  1],
#        [11, 11, 14, 15, 11, 13, 14, 21],
#        [14,  5, 12, 20, 29,  9, 25, 14],
#        [23, 13,  6, 39, 17,  9, 22, 24],
#        [13, 34,  7, 11, 22, 46, 11, 17],
#        [25,  3,  4, 39, 20,  6, 63, 28],
#        [27, 10, 11, 31, 20, 25, 22, 23]], dtype=int64)

# %%
# Calculate the accuracy score
# from sklearn.metrics import accuracy_score, classification_report
acc_score = accuracy_score(y_test, y_pred)

# %%
# Displaying results
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score : 0.19816053511705686
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.11      0.11      0.11       154
#            1       0.27      0.28      0.28       133
#            2       0.20      0.13      0.16       110
#            3       0.11      0.16      0.13       128
#            4       0.11      0.11      0.11       153
#            5       0.29      0.29      0.29       161
#            6       0.32      0.34      0.33       188
#            7       0.16      0.14      0.15       169
#
#     accuracy                           0.20      1196
#    macro avg       0.20      0.19      0.19      1196
# weighted avg       0.20      0.20      0.20      1196

# %%
import json
import pandas as pd
import numpy as np


from sqlalchemy import create_engine, func, inspect
import psycopg2

# from config import db_password
from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@group-10-final.cu1buh4bpqlm.us-east-2.rds.amazonaws.com:5432/group-10-final"
engine = create_engine(db_string)

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['GHG_food_sys_emi', 'country_def', 'cleaned_sector_emi']

# %% [markdown]
# ## cleaned_sector_emi

# %%
pd.read_sql_query('''SELECT * FROM cleaned_sector_emi LIMIT 5;''', engine)
# Out:
#    index Country_code_A3     Name      C_group_IM24_sh dev_country  \
# 0      0             AGO   Angola  10:_Southern_Africa           D
# 1      1             AGO   Angola  10:_Southern_Africa           D
# 2      2             AGO   Angola  10:_Southern_Africa           D
# 3      3             ALB  Albania   12:_Central Europe           I
# 4      4             ALB  Albania   12:_Central Europe           I
#
#      Substance   FOOD_system_stage      Y_1990      Y_1991      Y_1992  ...  \
# 0  GWP_100_CO2  LULUC (Production)  10273.5451  10273.5451  10273.5451  ...
# 1  GWP_100_CH4  LULUC (Production)   7662.4856   7662.4856   7662.4856  ...
# 2  GWP_100_N2O  LULUC (Production)   5009.7985   5009.7985   5009.7985  ...
# 3  GWP_100_CO2  LULUC (Production)    116.8068    116.8068    116.8068  ...
# 4  GWP_100_N2O  LULUC (Production)     12.4815     12.4815     12.4815  ...
#
#        Y_2009      Y_2010      Y_2011      Y_2012      Y_2013      Y_2014  \
# ...

# %%
clean_sector_df = pd.read_sql_query('''SELECT * FROM cleaned_sector_emi LIMIT 5;''', engine)

# %%
# Display the data table for preview
clean_sector_df.head()
# Out:
#    index Country_code_A3     Name      C_group_IM24_sh dev_country  \
# 0      0             AGO   Angola  10:_Southern_Africa           D
# 1      1             AGO   Angola  10:_Southern_Africa           D
# 2      2             AGO   Angola  10:_Southern_Africa           D
# 3      3             ALB  Albania   12:_Central Europe           I
# 4      4             ALB  Albania   12:_Central Europe           I
#
#      Substance   FOOD_system_stage      Y_1990      Y_1991      Y_1992  ...  \
# 0  GWP_100_CO2  LULUC (Production)  10273.5451  10273.5451  10273.5451  ...
# 1  GWP_100_CH4  LULUC (Production)   7662.4856   7662.4856   7662.4856  ...
# 2  GWP_100_N2O  LULUC (Production)   5009.7985   5009.7985   5009.7985  ...
# 3  GWP_100_CO2  LULUC (Production)    116.8068    116.8068    116.8068  ...
# 4  GWP_100_N2O  LULUC (Production)     12.4815     12.4815     12.4815  ...
#
#        Y_2009      Y_2010      Y_2011      Y_2012      Y_2013      Y_2014  \
# ...

# %%
ML_df = clean_sector_df.drop(clean_sector_df.columns[[0, 1, 3, 4, 6]], axis=1)

# %%
# Display the data table for preview
ML_df.head()
# Out:
#       Name    Substance      Y_1990      Y_1991      Y_1992      Y_1993  \
# 0   Angola  GWP_100_CO2  10273.5451  10273.5451  10273.5451  10273.5451
# 1   Angola  GWP_100_CH4   7662.4856   7662.4856   7662.4856   7662.4856
# 2   Angola  GWP_100_N2O   5009.7985   5009.7985   5009.7985   5009.7985
# 3  Albania  GWP_100_CO2    116.8068    116.8068    116.8068    116.8068
# 4  Albania  GWP_100_N2O     12.4815     12.4815     12.4815     12.4815
#
#        Y_1994      Y_1995      Y_1996      Y_1997  ...      Y_2009  \
# 0  10273.5451  10271.7160  10269.8864  10270.6118  ...  35606.0653
# 1   7662.4856   7662.4856  13344.3884  12118.1480  ...   6739.5328
# 2   5009.7985   5009.6395   3758.7865   3417.5195  ...   5869.6705
# 3    116.8068    116.8068    116.8068    116.8068  ...    116.6195
# 4     12.4815     12.4815     12.4815     12.4815  ...     12.4550
#
#        Y_2010      Y_2011      Y_2012      Y_2013      Y_2014      Y_2015  \
# ...

# %% [markdown]
# ## Country_def

# %%
pd.read_sql_query('''SELECT * FROM country_def LIMIT 5;''', engine)
# Out:
#   index   Country Name     Regional Grouping Country Class
# 0   ABW          Aruba  Rest Central America    Developing
# 1   AFG    Afghanistan               India +    Developing
# 2   AGO         Angola       Southern_Africa    Developing
# 3   AIA       Anguilla  Rest Central America    Developing
# 4   AIR  Int. Aviation         Int. Aviation             0

# %% [markdown]
# ## GHG_food_sys_emi

# %%
pd.read_sql_query('''SELECT * FROM GHG_food_sys_emi LIMIT 5;''', engine)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# UndefinedTable: relation "ghg_food_sys_emi" does not exist
# LINE 1: SELECT * FROM GHG_food_sys_emi LIMIT 5;
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # store your query in a pandas DataFrame
# Create a dataframe object using the command pd.read_sql()
# 1 - Your SQL query encapsulated in quotes.
# 2 - The engine object you created earlier using the create_engine() function.
#
# example_df = pd.read_sql('SELECT * FROM table Limit 3', engine)
# example_df
#
# When we have the queary in a DF we can run the ML projection for future emissions
#
# # Initial imports for Random Forest
# import pandas as pd
# from path import Path
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
#
# # Loading data example
# file_path = Path("../Resources/loans_data_encoded.csv")
# df_loans = pd.read_csv(file_path)
# df_loans.head()

# %% [markdown]
# # ML Secton

# %%
# Separate the Features (X) from the Target (y)
# Segment the features from the target
y = ML_df.loc[:, 'Y_1990':'Y_2018']
X = ML_df.drop[:'2']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_55436/867751372.py in <module>
#       1 # Separate the Features (X) from the Target (y)
#       2 # Segment the features from the target
# ----> 3 y = ML_df[:'2']
#       4 X = ML_df.drop[:'2']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3428
#    3429         # Do we have a slicer (on rows)?
# -> 3430         indexer = convert_to_index_sliceable(self, key)
#    3431         if indexer is not None:
#    3432             if isinstance(indexer, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2327     idx = obj.index
#    2328     if isinstance(key, slice):
# -> 2329         return idx._convert_slice_indexer(key, kind="getitem")
#    2330
#    2331     elif isinstance(key, str):
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_55436/1594169196.py in <module>
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X,
#       4                                                     y,
#       5                                                     random_state=1,
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2452         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2453
# -> 2454         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2455
#    2456     return list(
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1611         """
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_55436/3959894982.py in <module>
# ----> 1 classifier.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1136             _dtype = [np.float64, np.float32]
#    1137
# -> 1138         X, y = self._validate_data(
#    1139             X,
#    1140             y,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# --> 596                 X, y = check_X_y(X, y, **check_params)
#     597             out = X, y
#     598
#
# ...

# %%
y_pred = classifier.predict(X_test)
results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
results.head(20)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_55436/1357682000.py in <module>
#       1 # Make predictions
# ----> 2 y_pred = classifier.predict(X_test)
#       3 results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
#       4 results.head(20)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     445             Vector containing the class labels for each sample.
#     446         """
# --> 447         scores = self.decision_function(X)
#     448         if len(scores.shape) == 1:
#     449             indices = (scores > 0).astype(int)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     425             this class would be predicted.
#     426         """
# --> 427         check_is_fitted(self)
#     428
# ...

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
matrix = confusion_matrix(y_test, y_pred)
print(matrix)

# %%
from sklearn.metrics import confusion_matrix, classification_report
matrix = confusion_matrix(y_test, y_pred)
print(matrix)

# %%
report = classification_report(y_test, y_pred)
print(report)

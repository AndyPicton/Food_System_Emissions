# %%
import pandas as pd

# %%
#import csv
country_def_df = pd.read_csv("country_def_1")
country_def_df
# Out:
#     index  country_name     regional_grouping   country_class
# 0     ABW         Aruba  Rest Central America      Developing
# 1     AFG   Afghanistan               India +      Developing
# 2     AGO        Angola       Southern_Africa      Developing
# 3     AIA      Anguilla  Rest Central America      Developing
# 4     ALB       Albania        Central Europe  Industrialised
# ..    ...           ...                   ...             ...
# 221   ZWE      Zimbabwe       Southern_Africa      Developing
# 222   YEM         Yemen           Middle_East      Developing
# 223   ZAF  South Africa       Southern_Africa      Developing
# 224   ZMB        Zambia       Southern_Africa      Developing
# 225   ZWE      Zimbabwe       Southern_Africa      Developing
#
# [226 rows x 4 columns]

# %%
# Out:
#     index country_name regional_grouping country_class
# 221   ZWE     Zimbabwe   Southern_Africa    Developing
# 225   ZWE     Zimbabwe   Southern_Africa    Developing

# %%
# Out:
#     index country_name regional_grouping country_class
# 224   ZMB       Zambia   Southern_Africa    Developing

# %%
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222     True
# 223     True
# 224    False
# 225     True
# Name: country_name, Length: 225, dtype: bool

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/81/2t9q95y15f71dnxb4ttr7g4m0000gn/T/ipykernel_74746/1993428366.py in <module>
# ----> 1 print(co_df1.loc[[222]])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ...

# %%
#return duplicated rows
co_df[co_df.duplicated(['country_name'], keep=False)]
# Out:
#     index  country_name regional_grouping country_class
# 218   YEM         Yemen       Middle_East    Developing
# 219   ZAF  South Africa   Southern_Africa    Developing
# 221   ZWE      Zimbabwe   Southern_Africa    Developing
# 222   YEM         Yemen       Middle_East    Developing
# 223   ZAF  South Africa   Southern_Africa    Developing
# 225   ZWE      Zimbabwe   Southern_Africa    Developing

# %%
co_df1 = co_df.drop([218, 219, 221])

# %%
#return duplicates, nice!
co_df1[co_df1.duplicated(['country_name'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [index, country_name, regional_grouping, country_class]
# Index: []

# %%
co_df1.to_csv('/Users/cameronchapa/Downloads/School Related/Bootcamp Stuff/Analysis Projects/Final Project/Group_10_Final_Project/Cam/cleaned_country_data.csv', index = False)

# %%
pwd
# Out:
# '/Users/cameronchapa/Downloads/School Related/Bootcamp Stuff/Analysis Projects/Final Project/Group_10_Final_Project/Cam'

# %%
co_df1
# Out:
#     index  country_name     regional_grouping   country_class
# 0     ABW         Aruba  Rest Central America      Developing
# 1     AFG   Afghanistan               India +      Developing
# 2     AGO        Angola       Southern_Africa      Developing
# 3     AIA      Anguilla  Rest Central America      Developing
# 4     ALB       Albania        Central Europe  Industrialised
# ..    ...           ...                   ...             ...
# 217   WSM         Samoa               Oceania      Developing
# 222   YEM         Yemen           Middle_East      Developing
# 223   ZAF  South Africa       Southern_Africa      Developing
# 224   ZMB        Zambia       Southern_Africa      Developing
# 225   ZWE      Zimbabwe       Southern_Africa      Developing
#
# [222 rows x 4 columns]
